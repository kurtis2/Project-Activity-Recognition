# %% [markdown]
# # Comp255 Assignment 1

# %%
#import packages

import numpy as np 
import pandas as pd 
from scipy import signal
import matplotlib.pyplot as plt 
import math
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import make_scorer, accuracy_score, confusion_matrix
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Data Visualisation - task 1

# %%
# read and visualise the raw data 

def data_visulization():
    # read dataset file
    df = pd.read_csv('dataset_1.txt', sep=',', header=None)
    for i in range (1,14):
        df_activity = df[df[24] == i].values
        # Plot the accelerometer data
        print("Accelerometer for activity" + str(i))
        plt.plot(df_activity[500:1500, 0:3])
        plt.show()
        #plot the gyroscope data
        print("Gyroscope for activity" + str(i))
        plt.plot(df_activity[500:1500, 3:6])
        plt.show()

# %%
#function call
data_visulization()
# Out:
# Accelerometer for activity1
# Gyroscope for activity1
# Accelerometer for activity2
# Gyroscope for activity2
# Accelerometer for activity3
# Gyroscope for activity3
# Accelerometer for activity4
# Gyroscope for activity4
# Accelerometer for activity5
# Gyroscope for activity5
# Accelerometer for activity6
# Gyroscope for activity6
# Accelerometer for activity7
# Gyroscope for activity7
# Accelerometer for activity8
# Gyroscope for activity8
# Accelerometer for activity9
# Gyroscope for activity9
# Accelerometer for activity10
# Gyroscope for activity10
# Accelerometer for activity11
# Gyroscope for activity11
# Accelerometer for activity12
# Gyroscope for activity12
# Accelerometer for activity13
# Gyroscope for activity13

# %%
# apply sensoring and filtering a visulise the same data 

def noise_removing():
    # Butterworth low-pass filter. 
    b, a = signal.butter(4, 0.04, 'low', analog=False)
    df = pd.read_csv('dataset_1.txt', sep=',', header=None)
    for i in range(1,14):
        df_activity = df[df[24] == i].values
    
        for j in range(3):
            df_activity[:,j] = signal.lfilter(b, a, df_activity[:, j])
        # Plot the accelerometer data
        print("Accelerometer for activity" + str (i))
        plt.plot(df_activity[500:1500, 0:3])
        plt.show()

        for j in range(3,6):
            df_activity[:,j] = signal.lfilter(b, a, df_activity[:, j])
        #plot the gyroscope data
        print("Gyroscope for activity" + str(i))
        plt.plot(df_activity[500:1500, 3:6])
        plt.show()

# %%
noise_removing()
# Out:
# Accelerometer for activity1
# Gyroscope for activity1
# Accelerometer for activity2
# Gyroscope for activity2
# Accelerometer for activity3
# Gyroscope for activity3
# Accelerometer for activity4
# Gyroscope for activity4
# Accelerometer for activity5
# Gyroscope for activity5
# Accelerometer for activity6
# Gyroscope for activity6
# Accelerometer for activity7
# Gyroscope for activity7
# Accelerometer for activity8
# Gyroscope for activity8
# Accelerometer for activity9
# Gyroscope for activity9
# Accelerometer for activity10
# Gyroscope for activity10
# Accelerometer for activity11
# Gyroscope for activity11
# Accelerometer for activity12
# Gyroscope for activity12
# Accelerometer for activity13
# Gyroscope for activity13

# %% [markdown]
# ## Feature Engineering - task 2

# %%
# Print out features for all 19 sets of data 
def create_features():
    b, a = signal.butter(4, 0.04, 'low', analog=False) # create a butterworth low pass filter

    for i in range(19): #read all 19 datasets
            df = pd.read_csv('dataset_' + str(i + 1) + '.txt', sep=',', header=None)
            print("") # used only to place a space between datasets 
            print('deal with dataset ' + str(i + 1))

            for c in range(1, 14): #seperate each activity in each dataset
                print("Activity" + str(c))
                Activity_data = df[df[24] == c].values

                for j in range (24): # clean data of each sensor 
                    Activity_data[:,i] = signal.lfilter(b, a, Activity_data[:, i])

                #create features
                minVal = np.min(Activity_data[:, c])
                maxVal = np.max(Activity_data[:, c])
                meanVal = np.mean(Activity_data[:, c])
                medianVal = np.median(Activity_data[:, c])

                print("minVal = " + str(minVal) + ", maxVal = " + str(maxVal) +  ", meanVal = " + str(meanVal)
                      +  ", medianVal = " + str(medianVal))

# %%
create_features()
# Out:
# deal with dataset 1
# Activity1
# minVal = 0.14400000000000002, maxVal = 2.6731, meanVal = 0.9494843344182261, medianVal = 0.94963
# Activity2
# minVal = 0.22715, maxVal = 1.6117, meanVal = 0.6148484115875986, medianVal = 0.61107
# Activity3
# minVal = -22.149, maxVal = 10.806, meanVal = 0.666524806737733, medianVal = 0.55305
# Activity4
# minVal = -208.05, maxVal = 217.07, meanVal = -0.015557020506143762, medianVal = 0.30105
# Activity5
# minVal = -173.63, maxVal = 213.04, meanVal = -1.8950887476605092, medianVal = -4.8274
# Activity6
# minVal = -1.2929, maxVal = 0.8982700000000001, meanVal = 0.08513081552216135, medianVal = 0.10114
# Activity7
# minVal = -2.1951, maxVal = -0.22421, meanVal = -0.9837465121777744, medianVal = -1.0198
# Activity8
# minVal = -0.80697, maxVal = 0.42333000000000004, meanVal = -0.02807243489373923, medianVal = -0.0028536
# Activity9
# minVal = -89.12, maxVal = 65.768, meanVal = 2.878335652548456, medianVal = 2.4211
# Activity10
# minVal = -223.5, maxVal = 244.46, meanVal = 0.10790717053195323, medianVal = -5.2645
# Activity11
# minVal = -30.305999999999997, maxVal = 26.084, meanVal = 0.6958967078976276, medianVal = -0.64632
# Activity12
# minVal = -1.2426, maxVal = -0.66937, meanVal = -0.9707720222158928, medianVal = -0.97706
# Activity13
# minVal = -5.3976, maxVal = 7.4222, meanVal = 0.023002248864957, medianVal = -0.07483
#
# deal with dataset 2
# Activity1
# minVal = -0.7903924430449286, maxVal = 1.0134845584662426, meanVal = 0.13195808371809714, medianVal = -0.28995720439968875
# Activity2
# minVal = 0.83162, maxVal = 0.93781, meanVal = 0.9008268443893366, medianVal = 0.90105
# Activity3
# minVal = -135.29, maxVal = 99.78399999999999, meanVal = 0.9939236784177424, medianVal = 0.91922
# Activity4
# minVal = -159.35, maxVal = 124.07, meanVal = 1.5110546714664017, medianVal = 1.0334
# Activity5
# minVal = -239.17, maxVal = 146.77, meanVal = -0.2647953136378681, medianVal = -3.3627
# Activity6
# minVal = -0.95516, maxVal = 0.8275899999999999, meanVal = -0.09179913056636937, medianVal = -0.11875999999999999
# Activity7
# minVal = -1.7549, maxVal = -0.22421, meanVal = -1.0009487295012254, medianVal = -1.036
# Activity8
# minVal = -0.62202, maxVal = 0.25445999999999996, meanVal = -0.10721880473760124, medianVal = -0.087286
# Activity9
# minVal = -112.92, maxVal = 68.331, meanVal = 2.2187754546722456, medianVal = 0.95647
# Activity10
# minVal = -206.29, maxVal = 257.28, meanVal = -0.799761484545234, medianVal = 1.6926
# Activity11
# minVal = -29.94, maxVal = 32.675, meanVal = 0.7682775571610033, medianVal = -0.28015
# Activity12
# minVal = -1.2468, maxVal = -0.6735800000000001, meanVal = -0.9405108923822001, medianVal = -0.9391200000000001
# Activity13
# minVal = -4.0488, maxVal = 3.8762, meanVal = -0.05450435780365009, medianVal = -0.078651
#
# deal with dataset 3
# Activity1
# minVal = -1.3791, maxVal = 2.2563, meanVal = 0.11432840028136378, medianVal = 0.027764999999999998
# Activity2
# minVal = 5.405111376530217e-118, maxVal = 0.7621175290442065, meanVal = 0.6351160416682105, medianVal = 0.6737693831515138
# Activity3
# minVal = -100.51, maxVal = 167.16, meanVal = -1.6801073970707892, medianVal = -1.6439
# Activity4
# minVal = -135.91, maxVal = 91.11, meanVal = -1.9671193347438662, medianVal = -2.2621
# Activity5
# minVal = -141.77, maxVal = 110.88, meanVal = -17.708367561965986, medianVal = -20.573
# Activity6
# minVal = -0.66851, maxVal = 0.9768, meanVal = 0.16822549402672493, medianVal = 0.17967
# Activity7
# minVal = -1.8639, maxVal = -0.058621000000000006, meanVal = -0.9512717250843685, medianVal = -1.0198
# Activity8
# minVal = -0.15162, maxVal = 0.74095, meanVal = 0.24461091515613875, medianVal = 0.2424
# Activity9
# minVal = -371.43, maxVal = 278.51, meanVal = 4.126912270888548, medianVal = 5.3505
# Activity10
# minVal = -157.59, maxVal = 182.58, meanVal = -0.1490780331203967, medianVal = 3.1573
# Activity11
# minVal = -37.629, maxVal = 42.927, meanVal = 0.5654635600112058, medianVal = 1.1845
# Activity12
# minVal = -1.1752, maxVal = -0.55978, meanVal = -0.8517997146516189, medianVal = -0.8590399999999999
# Activity13
# minVal = -4.0411, maxVal = 2.4012, meanVal = -0.10309461784861385, medianVal = -0.12833
#
# deal with dataset 4
# Activity1
# minVal = -0.18066, maxVal = 0.24821, meanVal = 0.16541837594922287, medianVal = 0.17606
# Activity2
# minVal = 0.022935, maxVal = 1.0358, meanVal = 0.6858001828464482, medianVal = 0.68867
# Activity3
# minVal = -124.32457631617162, maxVal = 118.63240287723282, meanVal = 0.8643918932389159, medianVal = 0.3710490270727902
# Activity4
# minVal = -208.78, maxVal = 254.42, meanVal = 0.9124175016140745, medianVal = -0.43128
# Activity5
# minVal = -129.69, maxVal = 148.96, meanVal = -2.147983306419879, medianVal = -5.9259
# Activity6
# minVal = -0.6371, maxVal = 0.71764, meanVal = 0.13774743069250697, medianVal = 0.13255
# Activity7
# minVal = -2.0861, maxVal = -0.22825, meanVal = -0.9131025060783611, medianVal = -0.90675
# Activity8
# minVal = -0.14759, maxVal = 0.7892, meanVal = 0.31777138794340376, medianVal = 0.31879
# Activity9
# minVal = -81.431, maxVal = 58.445, meanVal = -0.7220613567211626, medianVal = -1.2405
# Activity10
# minVal = -543.9, maxVal = 681.66, meanVal = -0.627748865708982, medianVal = -15.151
# Activity11
# minVal = -70.584, maxVal = 76.615, meanVal = -0.3070070201068779, medianVal = -0.28015
# Activity12
# minVal = -1.4407, maxVal = -0.2816, meanVal = -0.8321107761760831, medianVal = -0.8295399999999999
# Activity13
# minVal = -5.3556, maxVal = 2.4012, meanVal = -0.3519701015333147, medianVal = -0.22385
#
# deal with dataset 5
# Activity1
# minVal = -1.0344, maxVal = 1.1821, meanVal = -0.08353957443252762, medianVal = -0.084462
# Activity2
# minVal = 0.28841, maxVal = 1.5219, meanVal = 0.8912863691105866, medianVal = 0.9051299999999999
# Activity3
# minVal = -256.5, maxVal = 271.15, meanVal = -0.05915921718610171, medianVal = -0.17928
# Activity4
# minVal = -136.8180729941191, maxVal = 85.10424694981246, meanVal = 1.4066254073503626, medianVal = 1.008493630924855
# Activity5
# minVal = -124.93, maxVal = 222.93, meanVal = 2.5497554932865416, medianVal = -0.4334
# Activity6
# minVal = -0.74705, maxVal = 0.9650200000000001, meanVal = 0.003789184713343745, medianVal = 0.030454000000000002
# Activity7
# minVal = -2.2678, maxVal = -0.038426999999999996, meanVal = -0.9850834945200979, medianVal = -0.97945
# Activity8
# minVal = -1.0603, maxVal = 0.8334299999999999, meanVal = -0.04284046333858268, medianVal = 0.0011669
# Activity9
# minVal = -443.57, maxVal = 161.34, meanVal = 3.145582009373169, medianVal = 3.1535
# Activity10
# minVal = -293.8, maxVal = 477.34, meanVal = 2.1210449338229367, medianVal = 5.3543
# Activity11
# minVal = -27.743000000000002, maxVal = 32.309, meanVal = 0.5899077452990071, medianVal = -1.0125
# Activity12
# minVal = -1.2890000000000001, maxVal = -0.68201, meanVal = -0.9906947416656662, medianVal = -0.99392
# Activity13
# minVal = -2.9292, maxVal = 6.0771, meanVal = 0.05486330342987806, medianVal = -0.067188
#
# deal with dataset 6
# Activity1
# minVal = -0.78588, maxVal = 1.7312, meanVal = 0.8450046841659885, medianVal = 0.9336
# Activity2
# minVal = 0.63966, maxVal = 0.78669, meanVal = 0.7158532484335584, medianVal = 0.71726
# Activity3
# minVal = -135.66, maxVal = 74.51899999999999, meanVal = 0.4773790048010416, medianVal = 0.55305
# Activity4
# minVal = -144.33, maxVal = 128.46, meanVal = -0.5002812108882289, medianVal = -0.43128
# Activity5
# minVal = -147.12629779253217, maxVal = 123.39326285437082, meanVal = 0.19159847175238925, medianVal = 4.769584437219331
# Activity6
# minVal = -0.8727, maxVal = 0.66266, meanVal = -0.22657761478888738, medianVal = -0.26798
# Activity7
# minVal = -2.0780000000000003, maxVal = -0.0061178000000000005, meanVal = -0.9647227782763202, medianVal = -1.0279
# Activity8
# minVal = -0.4612, maxVal = 0.59621, meanVal = 0.10211451800428673, medianVal = 0.11775999999999999
# Activity9
# minVal = -44.81399999999999, maxVal = 47.826, meanVal = 0.3948753661356628, medianVal = 0.5903
# Activity10
# minVal = -261.58, maxVal = 275.22, meanVal = 0.09754527215240556, medianVal = 1.6926
# Activity11
# minVal = -50.07899999999999, maxVal = 52.448, meanVal = 0.4682780271798837, medianVal = 0.45218
# Activity12
# minVal = -1.2637, maxVal = -0.7115199999999999, meanVal = -0.989219256770855, medianVal = -0.98549
# Activity13
# minVal = -2.1229, maxVal = 2.3974, meanVal = -0.10620596605181942, medianVal = -0.10922
#
# deal with dataset 7
# Activity1
# minVal = 0.13598, maxVal = 0.7812899999999999, meanVal = 0.4988363051261189, medianVal = 0.50473
# Activity2
# minVal = 0.64782, maxVal = 1.0562, meanVal = 0.8534896435836928, medianVal = 0.8520399999999999
# Activity3
# minVal = -339.25, maxVal = 246.98, meanVal = -0.13103062494914128, medianVal = 0.91922
# Activity4
# minVal = -244.66, maxVal = 236.84, meanVal = 1.2131408184481423, medianVal = 1.7657
# Activity5
# minVal = -242.47, maxVal = 163.98, meanVal = -0.5815074394909557, medianVal = 4.6929
# Activity6
# minVal = -0.678184256279576, maxVal = 0.5385695564885244, meanVal = -0.06909332268047423, medianVal = -0.1067838500428276
# Activity7
# minVal = -1.9972, maxVal = -0.17574, meanVal = -0.9900472755865567, medianVal = -0.9875200000000001
# Activity8
# minVal = -0.75068, maxVal = 0.35096, meanVal = -0.05144258026472823, medianVal = -0.022956999999999998
# Activity9
# minVal = -75.206, maxVal = 60.275, meanVal = -1.9181327938484072, medianVal = -0.87436
# Activity10
# minVal = -248.03, maxVal = 241.17, meanVal = 1.4602455659532922, medianVal = 0.96031
# Activity11
# minVal = -37.995, maxVal = 46.955, meanVal = 1.2097999681002563, medianVal = 0.81835
# Activity12
# minVal = -1.192, maxVal = -0.58086, meanVal = -0.9161783163119992, medianVal = -0.91805
# Activity13
# minVal = -4.4614, maxVal = 1.4383, meanVal = -0.4161422098621421, medianVal = -0.2506
#
# deal with dataset 8
# Activity1
# minVal = -1.0865, maxVal = 1.9196, meanVal = -0.06820948806619777, medianVal = -0.12053
# Activity2
# minVal = -0.37732, maxVal = 1.5749, meanVal = 0.8940446254882155, medianVal = 0.96231
# Activity3
# minVal = -579.45, maxVal = 409.93, meanVal = -0.3701405462962962, medianVal = -1.2778
# Activity4
# minVal = -190.11, maxVal = 175.69, meanVal = 0.7787712301647849, medianVal = 0.30105
# Activity5
# minVal = -175.09, maxVal = 180.82, meanVal = 0.6610948883083506, medianVal = -1.5319
# Activity6
# minVal = -0.9865799999999999, maxVal = 0.86685, meanVal = 0.11256112754435678, medianVal = 0.14826
# Activity7
# minVal = -1.5277557638930988, maxVal = -1.0288159221190515e-117, meanVal = -0.9507854163554949, medianVal = -0.9537078687468221
# Activity8
# minVal = -0.93563, maxVal = 4.2992, meanVal = 0.16368789298887984, medianVal = 0.15797
# Activity9
# minVal = -540.97, maxVal = 200.52, meanVal = -11.697405362622037, medianVal = -10.395
# Activity10
# minVal = -320.9, maxVal = 209.31, meanVal = -21.567024248216, medianVal = -25.404
# Activity11
# minVal = -35.798, maxVal = 30.112, meanVal = 0.20364347176001862, medianVal = 1.1845
# Activity12
# minVal = -1.251, maxVal = -0.54714, meanVal = -0.9479471147821134, medianVal = -0.96441
# Activity13
# minVal = -4.5149, maxVal = 3.345, meanVal = -0.0792441430752282, medianVal = -0.0060505
#
# deal with dataset 9
# Activity1
# minVal = 0.24019000000000001, maxVal = 0.37246, meanVal = 0.3075485653836764, medianVal = 0.30833
# Activity2
# minVal = 0.8683700000000001, maxVal = 0.99498, meanVal = 0.9353304996338189, medianVal = 0.9337200000000001
# Activity3
# minVal = -13.727, maxVal = 16.298, meanVal = 0.6588890976403581, medianVal = 0.55305
# Activity4
# minVal = -138.11, maxVal = 197.66, meanVal = -0.4222450770720687, medianVal = -0.06511499999999999
# Activity5
# minVal = -139.58, maxVal = 176.06, meanVal = -0.272593763466233, medianVal = -1.5319
# Activity6
# minVal = -7.6032, maxVal = 3.3446, meanVal = 0.031146280073641244, medianVal = 0.10114
# Activity7
# minVal = -3.6046, maxVal = 0.26850999999999997, meanVal = -0.9580971809900841, medianVal = -0.9834799999999999
# Activity8
# minVal = -0.3500999596379601, maxVal = 0.5071186684192619, meanVal = 0.0950609512638943, medianVal = 0.11841303809061124
# Activity9
# minVal = -140.38, maxVal = 89.569, meanVal = 1.0325906559877955, medianVal = 0.5903
# Activity10
# minVal = -195.3, maxVal = 174.52, meanVal = -0.26335685925865615, medianVal = 4.9881
# Activity11
# minVal = -70.584, maxVal = 52.448, meanVal = 0.980371767187996, medianVal = 0.81835
# Activity12
# minVal = -1.2805, maxVal = -0.58086, meanVal = -0.9975708665793338, medianVal = -1.0066
# Activity13
# minVal = -4.5073, maxVal = 6.0427, meanVal = -0.11007049439579684, medianVal = -0.090115
#
# deal with dataset 10
# Activity1
# minVal = -0.00029152, maxVal = 0.35241999999999996, meanVal = 0.20475254268123136, medianVal = 0.20412
# Activity2
# minVal = 0.74993, maxVal = 0.90922, meanVal = 0.8532726412908564, medianVal = 0.8520399999999999
# Activity3
# minVal = -354.99, maxVal = 395.28, meanVal = 1.6617542745544795, medianVal = 0.55305
# Activity4
# minVal = -221.96, maxVal = 224.03, meanVal = 1.7446121031859054, medianVal = 0.66722
# Activity5
# minVal = -521.12, maxVal = 160.31, meanVal = 2.267328554479616, medianVal = 9.0869
# Activity6
# minVal = -0.73527, maxVal = 0.92968, meanVal = 0.04432320308841697, medianVal = 0.038307
# Activity7
# minVal = -2.5142, maxVal = 0.098889, meanVal = -0.938214824385168, medianVal = -0.9713700000000001
# Activity8
# minVal = -0.36069, maxVal = 1.0626, meanVal = 0.22965494374867326, medianVal = 0.19818
# Activity9
# minVal = -43.84099582866264, maxVal = 38.23387579119255, meanVal = 1.2077122739884414, medianVal = 0.3291817059427311
# Activity10
# minVal = -338.48, maxVal = 462.33, meanVal = 1.9113656290004921, medianVal = 0.96031
# Activity11
# minVal = -38.728, maxVal = 38.167, meanVal = 1.1637290337636543, medianVal = 1.5507
# Activity12
# minVal = -1.4069999999999998, maxVal = -0.5766399999999999, meanVal = -0.9734632326972372, medianVal = -0.96441
# Activity13
# minVal = -7.098, maxVal = 5.5192, meanVal = -0.1976517930236761, medianVal = -0.21620999999999999
#
# deal with dataset 11
# Activity1
# minVal = 0.11194000000000001, maxVal = 0.73319, meanVal = 0.37189586723768736, medianVal = 0.37246
# Activity2
# minVal = 0.61107, maxVal = 1.1788, meanVal = 0.9051574033688663, medianVal = 0.9051299999999999
# Activity3
# minVal = -90.98899999999999, maxVal = 101.25, meanVal = 0.46218873137469474, medianVal = 0.91922
# Activity4
# minVal = -129.69, maxVal = 121.87, meanVal = 2.166821098391597, medianVal = 1.0334
# Activity5
# minVal = -513.43, maxVal = 352.18, meanVal = 1.9133718445155319, medianVal = 1.0313
# Activity6
# minVal = -0.72348, maxVal = 1.0868, meanVal = 0.17746156584065714, medianVal = 0.17967
# Activity7
# minVal = -2.0497, maxVal = -0.18382, meanVal = -0.9813089826217473, medianVal = -1.0037
# Activity8
# minVal = -0.42099, maxVal = 0.42735, meanVal = 0.05582116237239236, medianVal = 0.061475999999999996
# Activity9
# minVal = -196.04, maxVal = 88.47, meanVal = 0.3166371415724565, medianVal = -0.14203
# Activity10
# minVal = -157.28003438817896, maxVal = 154.8564978160599, meanVal = 1.764202896377926, medianVal = -4.748300796415451e-97
# Activity11
# minVal = -83.4, maxVal = 86.135, meanVal = 0.6998388167159035, medianVal = -0.64632
# Activity12
# minVal = -1.2552, maxVal = -0.45441000000000004, meanVal = -1.0000773047004303, medianVal = -1.0023
# Activity13
# minVal = -4.9353, maxVal = 3.3183, meanVal = -0.16131948117073172, medianVal = -0.10157999999999999
#
# deal with dataset 12
# Activity1
# minVal = -0.18066, maxVal = 0.55283, meanVal = 0.2836087778128286, medianVal = 0.25623
# Activity2
# minVal = 0.09236699999999999, maxVal = 3.3843, meanVal = 0.7660361587161838, medianVal = 0.77444
# Activity3
# minVal = -199.01, maxVal = 172.65, meanVal = 0.8171470689234275, medianVal = 0.18689
# Activity4
# minVal = -301.79, maxVal = 192.17, meanVal = 0.3058039509230877, medianVal = 1.0334
# Activity5
# minVal = -115.04, maxVal = 117.47, meanVal = -0.6027940907315484, medianVal = -1.8981
# Activity6
# minVal = -0.8295100000000001, maxVal = 0.86685, meanVal = 0.022308411761202285, medianVal = 0.03438
# Activity7
# minVal = -1.9245, maxVal = -0.010156, meanVal = -0.9950102506077754, medianVal = -1.036
# Activity8
# minVal = -0.7748, maxVal = 0.30673, meanVal = -0.10324057708864974, medianVal = -0.099348
# Activity9
# minVal = -43.716, maxVal = 41.601000000000006, meanVal = 2.514756037050945, medianVal = 2.055
# Activity10
# minVal = -408.05, maxVal = 328.68, meanVal = 1.5941259976401663, medianVal = -10.757
# Activity11
# minVal = -34.432129336079335, maxVal = 42.398525024742206, meanVal = 0.6153955194389257, medianVal = -2.832031196494748e-08
# Activity12
# minVal = -1.584, maxVal = -0.24366, meanVal = -0.9341241941731901, medianVal = -0.9686299999999999
# Activity13
# minVal = -1.7332, maxVal = 2.7872, meanVal = -0.0418096789402358, medianVal = -0.021335
#
# deal with dataset 13
# Activity1
# minVal = -1.1506, maxVal = 2.3444, meanVal = 0.6323020947290029, medianVal = 0.70113
# Activity2
# minVal = -0.41816000000000003, maxVal = 1.9099, meanVal = 0.749023652481191, medianVal = 0.80303
# Activity3
# minVal = -320.94, maxVal = 300.81, meanVal = 0.3836876532735709, medianVal = 0.91922
# Activity4
# minVal = -168.5, maxVal = 142.01, meanVal = 1.6054842254458883, medianVal = -0.06511499999999999
# Activity5
# minVal = -164.48, maxVal = 132.12, meanVal = 0.1758178988526321, medianVal = -0.067229
# Activity6
# minVal = -0.42112, maxVal = 0.92968, meanVal = 0.13039924235925254, medianVal = 0.13648
# Activity7
# minVal = -1.7953, maxVal = -0.22825, meanVal = -0.9376334898376388, medianVal = -0.90271
# Activity8
# minVal = -0.54161, maxVal = 0.8294100000000001, meanVal = 0.21571719131196793, medianVal = 0.2424
# Activity9
# minVal = -140.38, maxVal = 81.87899999999999, meanVal = -0.814645310550583, medianVal = 0.5903
# Activity10
# minVal = -660.34, maxVal = 416.93, meanVal = -0.3461472868942508, medianVal = 4.2558
# Activity11
# minVal = -54.107, maxVal = 89.431, meanVal = 0.9587621182713258, medianVal = 2.283
# Activity12
# minVal = -1.0674791130376728, maxVal = -8.127896330694304e-118, meanVal = -0.8710185253217307, medianVal = -0.8995361520011153
# Activity13
# minVal = -5.795, maxVal = 6.784, meanVal = -0.06611178635888502, medianVal = -0.14361
# deal with dataset 14
# Activity1
# minVal = 0.52477, maxVal = 0.86145, meanVal = 0.7293745974067551, medianVal = 0.72918
# Activity2
# minVal = 0.72951, maxVal = 0.87246, meanVal = 0.8009139270892668, medianVal = 0.79894
# Activity3
# minVal = -51.443000000000005, maxVal = 25.086, meanVal = 0.7953644161445195, medianVal = 0.91922
# Activity4
# minVal = -133.72, maxVal = 168.01, meanVal = 0.36664831914292634, medianVal = 0.30105
# Activity5
# minVal = -147.27, maxVal = 191.44, meanVal = -0.1365110729107335, medianVal = -1.5319
# Activity6
# minVal = -0.68029, maxVal = 0.8001, meanVal = -0.1068985204857286, medianVal = -0.13054000000000002
# Activity7
# minVal = -2.2718, maxVal = 0.88644, meanVal = -0.9547167154216498, medianVal = -1.0158
# Activity8
# minVal = -0.79089, maxVal = 1.0505, meanVal = 0.030771826730135485, medianVal = 0.049414
# Activity9
# minVal = -662.9, maxVal = 478.44, meanVal = 1.5325429139349978, medianVal = 9.7445
# Activity10
# minVal = -660.7, maxVal = 731.83, meanVal = -0.4587088729758319, medianVal = 15.607000000000001
# Activity11
# minVal = -97.68, maxVal = 110.67, meanVal = 0.658939211389923, medianVal = 0.45218
# Activity12
# minVal = -1.4154, maxVal = -0.49233999999999994, meanVal = -0.9859738193043337, medianVal = -0.98549
# Activity13
# minVal = -0.544175617982182, maxVal = 0.38212738233077154, meanVal = -0.03884455838829427, medianVal = -0.016899727124029436
#
# deal with dataset 15
# Activity1
# minVal = -0.66564, maxVal = 3.0098, meanVal = 0.31638515868350164, medianVal = 0.28829
# Activity2
# minVal = 0.24348000000000003, maxVal = 1.3503, meanVal = 0.8641228757034096, medianVal = 0.87246
# Activity3
# minVal = -39.725, maxVal = 59.872, meanVal = 0.7292056190003309, medianVal = 0.55305
# Activity4
# minVal = -212.81, maxVal = 226.23, meanVal = 2.976807351995768, medianVal = 2.8642
# Activity5
# minVal = -130.79, maxVal = 138.34, meanVal = -3.195059292255892, medianVal = -8.8552
# Activity6
# minVal = -0.696, maxVal = 0.70586, meanVal = 0.08035617311372957, medianVal = 0.081502
# Activity7
# minVal = -1.8195, maxVal = -0.29286999999999996, meanVal = -0.9076228409886125, medianVal = -0.8582799999999999
# Activity8
# minVal = -0.23605, maxVal = 0.6726, meanVal = 0.2690580201891782, medianVal = 0.27055
# Activity9
# minVal = -211.79, maxVal = 81.513, meanVal = 0.5332303319849352, medianVal = -0.5082
# Activity10
# minVal = -646.06, maxVal = 422.78, meanVal = 1.8062175321719705, medianVal = -5.6307
# Activity11
# minVal = -20.785, maxVal = 20.590999999999998, meanVal = 0.6585600182886462, medianVal = 0.45218
# Activity12
# minVal = -1.2342, maxVal = -0.58086, meanVal = -0.9726812152067772, medianVal = -0.9812700000000001
# Activity13
# minVal = -4.5379, maxVal = 7.4413, meanVal = 0.02258463826157596, medianVal = 0.051266
#
# deal with dataset 16
# Activity1
# minVal = -1.2027, maxVal = 2.9978, meanVal = 0.6041430819578485, medianVal = 0.5889
# Activity2
# minVal = 0.74993, maxVal = 1.0358, meanVal = 0.9177055928065748, medianVal = 0.91738
# Activity3
# minVal = -461.18, maxVal = 296.42, meanVal = -0.04018889357828518, medianVal = 0.55305
# Activity4
# minVal = -417.49, maxVal = 365.73, meanVal = 1.6647511355932203, medianVal = 0.66722
# Activity5
# minVal = -145.44, maxVal = 229.89, meanVal = -0.3735371547268283, medianVal = -2.9966
# Activity6
# minVal = -0.8569899999999999, maxVal = 0.70978, meanVal = 0.021944958318489114, medianVal = 0.014747
# Activity7
# minVal = -2.5586, maxVal = 0.33313000000000004, meanVal = -0.9581812953548239, medianVal = -0.9956
# Activity8
# minVal = -0.40893, maxVal = 0.6806399999999999, meanVal = 0.1733399338643371, medianVal = 0.17807
# Activity9
# minVal = -662.9, maxVal = 495.28, meanVal = 0.8303948614173223, medianVal = 6.449
# Activity10
# minVal = -660.7, maxVal = 731.83, meanVal = 2.3652047419169535, medianVal = 10.847000000000001
# Activity11
# minVal = -128.44, maxVal = 204.04, meanVal = 1.0389463059701491, medianVal = 0.81835
# Activity12
# minVal = -1.0951, maxVal = -0.39118, meanVal = -0.7622620358339885, medianVal = -0.75788
# Activity13
# minVal = -2.8757, maxVal = 5.2709, meanVal = 0.07490901165746566, medianVal = -0.059546
#
# deal with dataset 17
# Activity1
# minVal = -0.14057999999999998, maxVal = 0.29631, meanVal = 0.05876749968945094, medianVal = 0.055822000000000004
# Activity2
# minVal = 0.66825, maxVal = 0.8806299999999999, meanVal = 0.7894287514006724, medianVal = 0.79077
# Activity3
# minVal = -189.85, maxVal = 292.02, meanVal = 0.42071823251965257, medianVal = 0.18689
# Activity4
# minVal = -126.39, maxVal = 135.42, meanVal = 0.986031926801481, medianVal = 0.30105
# Activity5
# minVal = -102.23, maxVal = 87.08, meanVal = -0.38074624800650886, medianVal = 4.1437
# Activity6
# minVal = -0.9119700000000001, maxVal = 0.59591, meanVal = -0.28030215356580673, medianVal = -0.33866
# Activity7
# minVal = -1.973, maxVal = -0.21613000000000002, meanVal = -0.9385320790207903, medianVal = -0.95925
# Activity8
# minVal = -0.26419000000000004, maxVal = 0.65652, meanVal = 0.2233053679306046, medianVal = 0.23034000000000002
# Activity9
# minVal = -120.24, maxVal = 67.965, meanVal = 2.3573978442663996, medianVal = 1.6888
# Activity10
# minVal = -475.06, maxVal = 645.78, meanVal = 2.368140841844001, medianVal = -7.8277
# Activity11
# minVal = -64.359, maxVal = 67.094, meanVal = 0.810095906294503, medianVal = 0.45218
# Activity12
# minVal = -0.99813, maxVal = -0.44598000000000004, meanVal = -0.7210206358424266, medianVal = -0.72416
# Activity13
# minVal = -7.9081, maxVal = 2.1147, meanVal = -0.5082576763285024, medianVal = -0.025156
#
# deal with dataset 18
# Activity1
# minVal = -1.6075, maxVal = 4.092, meanVal = 0.33934885835788103, medianVal = 0.27626999999999996
# Activity2
# minVal = 0.31292, maxVal = 1.1788, meanVal = 0.7516383015847606, medianVal = 0.74993
# Activity3
# minVal = -317.65, maxVal = 305.94, meanVal = 0.739433787940434, medianVal = 0.55305
# Activity4
# minVal = -204.75, maxVal = 286.64, meanVal = 0.3259476693880816, medianVal = -2.2621
# Activity5
# minVal = -179.12, maxVal = 186.68, meanVal = -1.8237897547622857, medianVal = -4.0951
# Activity6
# minVal = -0.9748, maxVal = 0.78832, meanVal = -0.027936334185202184, medianVal = -0.020594
# Activity7
# minVal = -3.4027, maxVal = 2.8169, meanVal = -0.8377860826892668, medianVal = -0.8421299999999999
# Activity8
# minVal = -0.82305, maxVal = 1.2797, meanVal = 0.34678606917851834, medianVal = 0.37508
# Activity9
# minVal = -296.0, maxVal = 398.61, meanVal = -0.22957775663495236, medianVal = -0.14203
# Activity10
# minVal = -646.06, maxVal = 732.19, meanVal = -0.46192832770476416, medianVal = 9.3821
# Activity11
# minVal = -79.006, maxVal = 59.771, meanVal = 0.6306995850592017, medianVal = 0.81835
# Activity12
# minVal = -1.4323, maxVal = -0.5092, meanVal = -0.886265397062384, medianVal = -0.88854
# Activity13
# minVal = -2.8719, maxVal = 2.5197, meanVal = -0.34298266922856324, medianVal = -0.26588
#
# deal with dataset 19
# Activity1
# minVal = -0.040373, maxVal = 0.28829, meanVal = 0.13119226322895625, medianVal = 0.13198
# Activity2
# minVal = -0.9041899999999999, maxVal = 1.9875, meanVal = 0.8810914528440069, medianVal = 0.92555
# Activity3
# minVal = -294.58, maxVal = 293.49, meanVal = -0.25934602407610075, medianVal = -2.3763
# Activity4
# minVal = -183.51, maxVal = 211.95, meanVal = 4.542035487834899, medianVal = 3.5965
# Activity5
# minVal = -233.32, maxVal = 261.01, meanVal = -0.7190562424693812, medianVal = -0.79956
# Activity6
# minVal = -0.77061, maxVal = 2.147, meanVal = 0.1963847847603547, medianVal = 0.21500999999999998
# Activity7
# minVal = -1.6903, maxVal = -0.15150999999999998, meanVal = -0.8783905405540055, medianVal = -0.90271
# Activity8
# minVal = -0.31645999999999996, maxVal = 0.8736299999999999, meanVal = 0.31509323934270067, medianVal = 0.32281
# Activity9
# minVal = -152.47, maxVal = 197.22, meanVal = 0.818676253598698, medianVal = 0.95647
# Activity10
# minVal = -487.87, maxVal = 527.14, meanVal = -0.975533270026481, medianVal = -7.4615
# Activity11
# minVal = -39.094, maxVal = 57.94, meanVal = 0.6768758400130201, medianVal = 0.81835
# Activity12
# minVal = -1.2932, maxVal = -0.69466, meanVal = -0.9622885380397806, medianVal = -0.96441
# Activity13
# minVal = -2.2529, maxVal = 3.4444, meanVal = -0.07960642528380801, medianVal = -0.10157999999999999

# %%
def feature_engineering():
    training = np.empty(shape=(0, 73))
    testing = np.empty(shape=(0, 73))
    
    # declare the butterworth filter 
    b, a = signal.butter(4, 0.04, 'low', analog=False)
    
    # Read dataset from all 19 participants 
    for i in range(19):
        df = pd.read_csv('dataset_' + str(i + 1) + '.txt', sep=',', header=None)
        print('deal with dataset ' + str(i + 1))
        
        # Seperate each activity in each dataset
        for c in range(1, 14): 
                print("Deal with activity" + str(c))
                activity_data = df[df[24] == c].values
                
                # Apply the butterworth filter to each sensor
                for j in range(24):
                    activity_data[:, j] = signal.lfilter(b, a, activity_data[:, j])

                    # Seperate the training and testing sets 
                datat_len = len(activity_data)
                training_len = math.floor(datat_len * 0.8) # seperates 80% of data for training and 20% for testing
                training_data = activity_data[:training_len, :]
                testing_data = activity_data[training_len:, :]

                # Data segmentation - create feature sets 
                training_sample_number = training_len // 1000 + 1
                testing_sample_number = (datat_len - training_len) // 1000 + 1
                
                for s in range(training_sample_number):
                    if s < training_sample_number - 1:
                        sample_data = training_data[1000*s:1000*(s + 1), :]
                    else:
                        sample_data = training_data[1000*s:, :]
                
                # For each sensor extract a feature of min, max and mean value then store it in list feature sample
                # Feature sample is then added to training 
                    feature_sample = []
                    for i in range(24):
                        feature_sample.append(np.min(sample_data[:, i]))
                        feature_sample.append(np.max(sample_data[:, i]))
                        feature_sample.append(np.mean(sample_data[:, i]))
                    feature_sample.append(sample_data[0, -1])
                    feature_sample = np.array([feature_sample])
                    training = np.concatenate((training, feature_sample), axis=0)

                for s in range(testing_sample_number):
                    if s < training_sample_number - 1:
                        sample_data = testing_data[1000*s:1000*(s + 1), :]
                    else:
                        sample_data = testing_data[1000*s:, :]
                    
                    # For each sensor extract a feature of min, max and mean value then store it in list feature sample
                    # Feature sample is then added to testing 
                    feature_sample = []
                    for i in range(24):
                        feature_sample.append(np.min(sample_data[:, i]))
                        feature_sample.append(np.max(sample_data[:, i]))
                        feature_sample.append(np.mean(sample_data[:, i]))
                    feature_sample.append(sample_data[0, -1])
                    feature_sample = np.array([feature_sample])
                    testing = np.concatenate((testing, feature_sample), axis=0)

    df_training = pd.DataFrame(training)
    df_testing = pd.DataFrame(testing)
    df_training.to_csv('training_data.csv', index=None, header=None)
    df_testing.to_csv('testing_data.csv', index=None, header=None)

# %%
feature_engineering()
# Out:
# deal with dataset 1
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 2
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 3
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 4
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 5
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 6
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 7
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 8
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 9
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 10
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 11
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 12
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 13
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 14
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 15
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 16
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 17
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 18
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13
# deal with dataset 19
# Deal with activity1
# Deal with activity2
# Deal with activity3
# Deal with activity4
# Deal with activity5
# Deal with activity6
# Deal with activity7
# Deal with activity8
# Deal with activity9
# Deal with activity10
# Deal with activity11
# Deal with activity12
# Deal with activity13

# %%
zz = pd.read_csv('training_data.csv', sep=',', header=None)
zz.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.816569  0.108664 -0.226076  0.000002  1.443393  0.927937 -0.065288
# 1 -0.217447 -0.198166 -0.206716  0.943449  0.954813  0.949051  0.243267
# 2 -0.211469 -0.197433 -0.203718  0.944969  0.955278  0.949762  0.245285
# 3 -0.213779 -0.196743 -0.205430  0.944102  0.955904  0.950064  0.245366
# 4 -0.215321 -0.197745 -0.205251  0.945593  0.955816  0.950407  0.245322
#
#          7         8           9   ...         63         64        65  \
# 0  0.419068  0.222570 -170.282327  ... -55.170616  31.401154 -8.955628
# 1  0.260781  0.251630    0.119608  ...  -8.265413  -7.463545 -7.855515
# 2  0.255684  0.251104    0.224533  ...  -8.224574  -7.463536 -7.797145
# 3  0.256772  0.252069    0.127256  ...  -8.154258  -7.413360 -7.727807
# 4  0.259100  0.252390    0.130987  ...  -8.249071  -7.370738 -7.756666
#
#           66         67        68         69         70        71   72
# 0 -13.700559  35.874019  6.926723 -18.405557  48.937208 -2.949775  1.0
# 1   5.987726   6.838815  6.408531  -5.105384  -4.365510 -4.755980  1.0
# 2   6.089990   6.877332  6.418028  -5.139920  -4.267236 -4.727582  1.0
# 3   6.087055   6.975519  6.506448  -5.064112  -4.378773 -4.737936  1.0
# 4   6.020695   6.939519  6.395726  -5.161874  -4.427301 -4.752851  1.0
#
# [5 rows x 73 columns]
